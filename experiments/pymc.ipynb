# %%
import pymc3 as pm
print('Running on PyMC3 v{}'.format(pm.__version__))
# Out:
# Running on PyMC3 v3.8

# %%
with pm.Model() as model:
    v = pm.Exponential('v', 10)
    
    # sample = pm.sample_prior_predictive(2)
    sample = pm.sample(20)
    
    print(sample)
# Out:
# Only 20 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [v]
# Sampling 4 chains, 0 divergences: 100%|██████████| 2080/2080 [00:00<00:00, 5795.18draws/s]
# <MultiTrace: 4 chains, 20 iterations, 2 variables>
# /home/pedro/.local/lib/python3.6/site-packages/pymc3/sampling.py:496: UserWarning: The number of samples is too small to check convergence reliably.
#   warnings.warn("The number of samples is too small to check convergence reliably.")

# %%
pm.traceplot(sample, var_names=['v']);
