# %%
import pymc3 as pm
print('Running on PyMC3 v{}'.format(pm.__version__))
# Out:
# Running on PyMC3 v3.8

# %%
with pm.Model() as model:
    v = pm.Exponential('v', 10)
    
    # sample = pm.sample_prior_predictive(2)
    sample = pm.sample(2)
    
    print(sample)
# Out:
# Only 2 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [v]
# Sampling 4 chains, 0 divergences: 100%|██████████| 2008/2008 [00:00<00:00, 6245.52draws/s]
# <MultiTrace: 4 chains, 2 iterations, 2 variables>

# %%
pm.traceplot(sample, var_names=['v']);
# Out:
# /home/pedro/.local/lib/python3.6/site-packages/arviz/data/base.py:146: UserWarning: More chains (4) than draws (2). Passed array should have shape (chains, draws, *shape)
#   UserWarning,
